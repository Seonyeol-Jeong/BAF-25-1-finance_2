# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 연예인(나무위키 사이트까지) 지정

# %%
import pandas as pd

# 연예인 목록 데이터 (원하는 만큼 추가 가능)
data = [
    # 방탄소년단 - 빅히트 뮤직직
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '진',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '슈가',
        'url': 'https://namu.wiki/w/%EC%8A%88%EA%B0%80(%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8)/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0'
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '제이홉',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': 'RM',
        'url': 'https://namu.wiki/w/RM/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0'
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '지민',
        'url': 'https://namu.wiki/w/%EC%A7%80%EB%AF%BC/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0'
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '뷔',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '방탄소년단',
        '연예인 이름': '정국',
        'url': 'https://namu.wiki/w/%EC%A0%95%EA%B5%AD/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0'
    },
    # 투모로우바이투게더 - 빅히트 뮤직
    {
        '소속사': 'HYBE',
        '그룹': '투모로우바이투게더',
        '연예인 이름': '연준',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '투모로우바이투게더',
        '연예인 이름': '수빈',
        'url': 'https://namu.wiki/w/%ED%88%AC%EB%AA%A8%EB%A1%9C%EC%9A%B0%EB%B0%94%EC%9D%B4%ED%88%AC%EA%B2%8C%EB%8D%94/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EC%88%98%EB%B9%88'
    },
    {
        '소속사': 'HYBE',
        '그룹': '투모로우바이투게더',
        '연예인 이름': '범준',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '투모로우바이투게더',
        '연예인 이름': '태현',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '투모로우바이투게더',
        '연예인 이름': '휴닝카이',
        'url': ''
    },
    # 엔하이픈 - 빌리프랩 
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '정원',
        'url': 'https://namu.wiki/w/ENHYPEN/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#s-3.1'
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '희승',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '제이',
        'url': 'https://namu.wiki/w/ENHYPEN/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EC%A0%9C%EC%9D%B4'
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '제이크',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '성훈',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '선우',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '엔하이픈',
        '연예인 이름': '니키',
        'url': 'https://namu.wiki/w/ENHYPEN/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EB%8B%88%ED%82%A4'
    },
    # 아일릿 - 빌리프랩
    {
        '소속사': 'HYBE',
        '그룹': '아일릿',
        '연예인 이름': '윤아',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '아일릿',
        '연예인 이름': '민주',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '아일릿',
        '연예인 이름': '모카',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '아일릿',
        '연예인 이름': '원희',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '아일릿',
        '연예인 이름': '이로하',
        'url': ''
    },
    # 르세라핌 - 쏘스뮤직
    {
        '소속사': 'HYBE',
        '그룹': '르세라핌',
        '연예인 이름': '김채원',
        'url': 'https://namu.wiki/w/LE%20SSERAFIM/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EA%B9%80%EC%B1%84%EC%9B%90'
    },
    {
        '소속사': 'HYBE',
        '그룹': '르세라핌',
        '연예인 이름': '허윤진',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '르세라핌',
        '연예인 이름': '사쿠라',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '르세라핌',
        '연예인 이름': '카즈하',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '르세라핌',
        '연예인 이름': '홍은채',
        'url': 'https://namu.wiki/w/LE%20SSERAFIM/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%ED%99%8D%EC%9D%80%EC%B1%84'
    },
    # # 세븐틴 - 플레디스 (너무 많아요,, 시험 끝나고 정리하겟습니다ㅠㅠㅠ)
    # {
    #     '소속사': 'HYBE',
    #     '그룹': '세븐틴',
    #     '연예인 이름': '',
    #     'url': ''
    # },
    # 뉴진스 - 어도어
    {
        '소속사': 'HYBE',
        '그룹': '뉴진스',
        '연예인 이름': '민지',
        'url': 'https://namu.wiki/w/NewJeans/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EB%AF%BC%EC%A7%80'
    },
    {
        '소속사': 'HYBE',
        '그룹': '뉴진스',
        '연예인 이름': '하니',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '뉴진스',
        '연예인 이름': '다니엘',
        'url': 'https://namu.wiki/w/NewJeans/%EB%85%BC%EB%9E%80%20%EB%B0%8F%20%EC%82%AC%EA%B1%B4%20%EC%82%AC%EA%B3%A0#%EB%8B%A4%EB%8B%88%EC%97%98'
    },
    {
        '소속사': 'HYBE',
        '그룹': '뉴진스',
        '연예인 이름': '해린',
        'url': ''
    },
    {
        '소속사': 'HYBE',
        '그룹': '뉴진스',
        '연예인 이름': '혜인',
        'url': ''
    },
    ]


# 데이터프레임으로 변환
df = pd.DataFrame(data)

# CSV 파일로 저장
df.to_csv("HYBE_연예인목록.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### div 지정해서 텍스트 가져오기

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import csv

# 크롬 드라이버 설정
options = Options()
# options.add_argument("--headless=new")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64)")
options.add_argument("--lang=ko_KR")
options.add_argument("--window-size=1920x1080")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.implicitly_wait(5)

# 연예인 목록 CSV 불러오기
artist_df = pd.read_csv("HYBE_연예인목록.csv")

# 결과 저장 CSV
with open("HYBE_연예인_전체텍스트.csv", "w", newline='', encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(['소속사', '그룹', '연예인 이름', '텍스트'])

    for _, artist in artist_df.iterrows():
        url = str(artist['url']).strip()
        
        if not url.startswith("http"):
            # URL이 없으면 텍스트 없이 기본 정보만 기록
            writer.writerow([
                artist['소속사'],
                artist['그룹'],
                artist['연예인 이름'],
                ''
            ])
            print(f"ℹ️ URL 없음 → 텍스트 없이 기록: {artist['연예인 이름']}")
            continue

        try:
            driver.get(url)
            time.sleep(3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            # BEFORE: 페이지 전체 텍스트
            # text = soup.get_text(separator="\n", strip=True)

            # AFTER: 특정 div 텍스트만
            target_div = soup.find("div", class_="_2JSj-wae")
            text = target_div.get_text(separator="\n", strip=True) if target_div else ""

            writer.writerow([
                artist['소속사'],
                artist['그룹'],
                artist['연예인 이름'],
                text
            ])
        except Exception as e:
            print(f"❌ 크롤링 오류: {artist['연예인 이름']} → {e}")
            writer.writerow([
                artist['소속사'],
                artist['그룹'],
                artist['연예인 이름'],
                ''
            ])

driver.quit()
# Out:
# ℹ️ URL 없음 → 텍스트 없이 기록: 진
# ℹ️ URL 없음 → 텍스트 없이 기록: 제이홉
# ℹ️ URL 없음 → 텍스트 없이 기록: 뷔
# ℹ️ URL 없음 → 텍스트 없이 기록: 연준
# ℹ️ URL 없음 → 텍스트 없이 기록: 범준
# ℹ️ URL 없음 → 텍스트 없이 기록: 태현
# ℹ️ URL 없음 → 텍스트 없이 기록: 휴닝카이
# ℹ️ URL 없음 → 텍스트 없이 기록: 희승
# ℹ️ URL 없음 → 텍스트 없이 기록: 제이크
# ℹ️ URL 없음 → 텍스트 없이 기록: 성훈
# ℹ️ URL 없음 → 텍스트 없이 기록: 선우
# ℹ️ URL 없음 → 텍스트 없이 기록: 윤아
# ℹ️ URL 없음 → 텍스트 없이 기록: 민주
# ℹ️ URL 없음 → 텍스트 없이 기록: 모카
# ℹ️ URL 없음 → 텍스트 없이 기록: 원희
# ℹ️ URL 없음 → 텍스트 없이 기록: 이로하
# ℹ️ URL 없음 → 텍스트 없이 기록: 허윤진
# ℹ️ URL 없음 → 텍스트 없이 기록: 사쿠라
# ℹ️ URL 없음 → 텍스트 없이 기록: 카즈하
# ℹ️ URL 없음 → 텍스트 없이 기록: 하니
# ℹ️ URL 없음 → 텍스트 없이 기록: 해린
# ℹ️ URL 없음 → 텍스트 없이 기록: 혜인

# %%
df = pd.read_csv("HYBE_연예인_전체텍스트.csv")
artist_text = df[df['연예인 이름'] == '슈가']['텍스트'].values

print(artist_text[0])
# Out:
# 18
# 편집 요청
# 편집 요청
# 편집 권한이 부족합니다. 로그인된 사용자(이)여야 합니다. 해당 문서의
# ACL 탭
# 을 확인하시기 바랍니다.
# 편집 권한이 부족한 경우 아래의 '편집 요청' 버튼으로 편집 요청을 생성할 수 있습니다.
# [편집 요청 도움말]
# 편집 요청
# 닫기
# 토론
# 역사
# 슈가(방탄소년단)/논란 및 사건 사고
# 최근 수정 시각:
# 2025-03-23 09:41:31
# 분류
# 슈가(방탄소년단)
# 대한민국의 인물별 논란
# 방탄소년단/사건 사고
# 상위 문서:
# 슈가(방탄소년단)
# 관련 문서:
# 방탄소년단/논란 및 사건 사고
# 주의. 사건·사고 관련 내용을 설명합니다.
# 사건 사고 관련 서술 규정
# 을 유의하시기 바랍니다.
# [ 한국 음반 ]
# D-DAY
# 정규 1집
# 2023. 4. 21.
# [ 무료 음반 ]
# Agust D
# 믹스테입 1집
# 2016. 8. 16.
# D-2
# 믹스테입 2집
# 2020. 5. 22.
# [ 참여 음반 ]
# 오늘 취하면
# (Feat. 창모)
# 프로듀싱
# 2017. 4. 27.
# 신청곡
# 피처링
# 2019. 1. 22.
# We don't talk together
# (Feat.기리보이)
# 프로듀싱
# 2019. 7. 7.
# SUGA's Interlude
# 콜라보
# 2019. 12. 5.
# 에잇
# 프로듀싱
# 피처링
# 2020. 5. 6.
# Blueberry Eyes
# 피처링
# 2020. 9. 16.
# Girl of My Dreams
# 콜라보
# 2021. 12. 10.
# Stay Alive
# 프로듀싱
# 2022. 2. 11.
# That That
# 프로듀싱
# 피처링
# 2022. 4. 29.
# [ 관련 문서 ]
# 음반
# 슈가 쿠키
# 사건 사고
# 1
# . 짐 존스 연설 샘플링
# 2
# . 군대 관련 가사 논란
# 3
# . 코로나바이러스감염증-19 관련 실언 논란
# 4
# .
# ...

# %% [markdown]
# ### 텍스트 정리
#
# `소속사`, `연예인`, `사건 날짜`, `사건 내용`
#
# `사건 내용`: 제목을 포함한 모든 텍스트

# %%
import re
import pandas as pd

# 날짜 정규표현식 (예: 2020년 1월 2일 또는 2020년 01월 02일 등)
date_pattern = re.compile(r'\d{4}년\s?\d{1,2}월\s?\d{1,2}일')

# 결과 리스트 초기화
date_separated_data = []

# 각 연예인 텍스트에 대해 처리
for _, row in df.iterrows():
    full_text = str(row['텍스트'])  # ✅ 문자열로 변환 (NaN 방지)
    matches = list(date_pattern.finditer(full_text))

    if not matches:
        date_separated_data.append({
            '소속사': row['소속사'],
            '그룹': row['그룹'],
            '연예인 이름': row['연예인 이름'],
            '사건 날짜': '',
            '사건 내용 (날짜+내용 전체)': full_text.strip()
        })
    else:
        for i, match in enumerate(matches):
            start = match.start()
            end = matches[i + 1].start() if i + 1 < len(matches) else len(full_text)
            date = match.group()
            content = full_text[start:end].strip()
            date_separated_data.append({
                '소속사': row['소속사'],
                '그룹': row['그룹'],
                '연예인 이름': row['연예인 이름'],
                '사건 날짜': date,
                '사건 내용 (날짜+내용 전체)': content
            })

# 결과 DataFrame 생성 및 저장
date_df = pd.DataFrame(date_separated_data)
date_df.to_csv("HYBE_연예인_전체텍스트_전처리1.csv", index=False, encoding='utf-8-sig')
